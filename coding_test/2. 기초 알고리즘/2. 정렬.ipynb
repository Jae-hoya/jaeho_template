# %% [markdown]
# # 정렬
# 배열이 주어지면, 원소를 순서에 맞게 재배치 하는것. 데이터를 정리하기 쉽다.
#
# ex) 배열 A에서 x라는 값이 있는지?
#
# 1. 배열 A가 정렬이 안되어있을때
# x가 있냐 없냐를 앞에서부터 체크.
# 시간복잡도 O(N)
#
# 2. 배열 A가 정렬이 되어있을때
# x가 정렬이 되어있다면, 이분탐색을 통해 빨리 찾을 수 있다.
# 시간복잡도 O(log<sub>2</sub>N)

# %% [markdown]
# # 1946: 신입사원
# https://www.acmicpc.net/problem/1946

# %%
# 문제
# 언제나 최고만을 지향하는 굴지의 대기업 진영 주식회사가 신규 사원 채용을 실시한다. 
# 인재 선발 시험은 1차 서류심사와 2차 면접시험으로 이루어진다.
# 최고만을 지향한다는 기업의 이념에 따라 그들은 최고의 인재들만을 사원으로 선발하고 싶어 한다.

# 그래서 진영 주식회사는, 다른 모든 지원자와 비교했을 때 서류심사 성적과 면접시험 성적 중 적어도 하나가
# 다른 지원자보다 떨어지지 않는 자만 선발한다는 원칙을 세웠다. 
# 즉, 어떤 지원자 A의 성적이 다른 어떤 지원자 B의 성적에 비해 서류 심사 결과와 면접 성적이 모두 떨어진다면 A는 결코 선발되지 않는다.

# 이러한 조건을 만족시키면서, 진영 주식회사가 이번 신규 사원 채용에서 선발할 수 있는 
# 신입사원의 최대 인원수를 구하는 프로그램을 작성하시오.

# 입력
# 첫째 줄에는 테스트 케이스의 개수 T(1 ≤ T ≤ 20)가 주어진다. 
# 각 테스트 케이스의 첫째 줄에 지원자의 숫자 N(1 ≤ N ≤ 100,000)이 주어진다. 
# 둘째 줄부터 N개 줄에는 각각의 지원자의 서류심사 성적, 면접 성적의 순위가 공백을 사이에 두고 한 줄에 주어진다. 
# 두 성적 순위는 모두 1위부터 N위까지 동석차 없이 결정된다고 가정한다.

# 출력
# 각 테스트 케이스에 대해서 진영 주식회사가 선발할 수 있는 신입사원의 최대 인원수를 한 줄에 하나씩 출력한다.

# %%
# 가장 잘본, 동등한 성적을 가진 사람을 뽑아야한다.
# 지원자마다 n-1명, 총비교 (n(n-1)) = o(n^2)
# import sys
# input = sys.stdin.readline # 입력을 발리 받기 위함

T = int(input()) # 테스트 케이스 수.


for _ in range(T): # 테스트 케이수 T개
    N = int(input()) # 지원자 수.
    candidates = []
    
    for _ in range(N):
        s, m = map(int, input().split()) #서류 성적 순위와 면접 성적 순위
        candidates.append((s, m))
        
    # (s, m)
    candidates.sort() # 첫번째걸 기준으로 정렬(작은것부터 정렬) # 서류 기준으로 이미 정렬
    
    top_ranking = 1e9 # 무한대
    count = 0
    
    for i in range(N):
        if candidates[i][1] < top_ranking: # 면접기준 기준
            count +=1
            top_ranking = candidates[i][1]
        else:
            #하위 호환 케이스
            pass
        
    print(count)
# Out:
# 4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 14
#      11 candidates = []
#      13 for _ in range(N):
# ---> 14     s, m = map(int, input().split()) #서류 성적 순위와 면접 성적 순위
#      15     candidates.append((s, m))
#      17 # (s, m)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %% [markdown]
# # 11728: 배열 합치기
# https://www.acmicpc.net/problem/11728

# %%
N, M = map(int, input().split())

A =  list(map(int, input().split()))
B =  list(map(int, input().split()))
C = []


pos1 = 0
pos2 = 0

while pos1 < N and pos2 < M:
    candidate1 = A[pos1]
    candidate2 = B[pos2]
    
    if candidate1 < candidate2:
        C.append(candidate1)
        pos1 +=1
    else:
        C.append(candidate2)
        pos2 += 1
        
if pos1 != N:
    C.extend(A[pos1:N])
if pos2 != M:
    C.extend(B[pos2:M])
    
for i in range(N+M):
    print(C[i], end = ' ')
# Out:
# 1 3 5 9
